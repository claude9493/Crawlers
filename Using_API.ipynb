# %% [markdown]
# # 来碗毒鸡汤

# %%
# 页面貌似挂了
def onemore():
    import requests
    import bs4
    url = "http://www.nows.fun/"
    headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
    response = requests.get(url, headers=headers)
    print(bs4.BeautifulSoup(response.text, 'html.parser', parse_only=bs4.SoupStrainer(id="sentence")).text)
onemore()

# %% [markdown]
# # Yes or No

# %%
# API of yesno.wtf
def tellMe():
    import json
    from IPython.display import HTML
    url = "https://yesno.wtf/api"
    response = json.loads(requests.get(url).text)
    print(response["answer"])
    return(HTML('<img src={}>'.format(response["image"])))
tellMe()
# Out:
# no
# <img src=https://yesno.wtf/assets/no/18-1ba72d815ec0e2bff8dba8699a50e275.gif>

# %% [markdown]
# # Cats

# %%
def giveMeCat():
    url = "https://api.thecatapi.com/v1/images/search"
    response = json.loads(requests.get(url).text)
    return((HTML('<img src={} width=200>'.format(response[0]['url']))))
giveMeCat()
# Out:
# <img src=https://cdn2.thecatapi.com/images/ece.jpg width=200>

# %% [markdown]
# # Dogs

# %%
def giveMeDog():
    url = "https://random.dog/woof.json"
    response = json.loads(requests.get(url).text)
    return((HTML('<img src={} width=200>'.format(response['url']))))
giveMeDog()
# Out:
# <img src=https://random.dog/c61a3df2-abe3-4b0a-84ee-d036f8696814.jpg width=200>

# %% [markdown]
# # Joke

# %%
def Joke():
    url = "http://api.icndb.com/jokes/random/"
    response = json.loads(requests.get(url).text)
    return(response["value"]["joke"])
Joke()
# Out:
# "When Chuck Norris calls 1-900 numbers, he doesn't get charged. He holds up the phone and money falls out."
